# %% [markdown]
# # Capstone Project - Are open air festivals and temperature related?
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Introduction

# %% [markdown]
# We have been contacted by an investor wanting to create a new open air festival in Europe. Among other aspects, the client wants to see if there is any correlation between the number of existing festivals and some weather conditions, specifically temperature. For this reason, we will conduct a clustering analysis of a list of different cities in Europe and its monthly temperatures, along with the number of festivals in each city extracted from Foursquare.

# %% [markdown]
# ## Data

# %% [markdown]
# In this analysis we will use mean monthly temperatures extracted from [Wikipedia](https://en.wikipedia.org/wiki/List_of_cities_by_average_temperature) and foursquare data of festivals in the different locations.
#
# For the temperatures, I will extract the data using BeautifulSoup and create a Pandas Dataframe. I will later use KNN clustering to cluster the data based on temperatures. In the last step I will get the number of festivals per location in a 10 Km radius and check if there is any correlation to the different clusters.

# %% [markdown]
# ## Methodology
#
# First of all, let's import all necessary packages to conduct our research and define a function to manipulate strings and get only temperature in degrees Celsius

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
import folium
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
import seaborn as sns

# %%
def func(string):
    a_new_string =string.split('(')[0] 
    return a_new_string

# %% [markdown]
# We will use Pandas to directly read the tabular wikipedia data into a dataframe. For that we will define the url and read in the data. Finally, we will clean the dataframe.

# %%
url = 'https://en.wikipedia.org/wiki/List_of_cities_by_average_temperature'

df_list = pd.read_html(url, flavor='bs4')

## As the dataframe is a list of dataframes we will select the one corresponding to Europe
dfeurope= df_list[2]
dfeurope.drop('Ref.', axis=1, inplace=True)

## Remove temperatures in Farenheit
for col in dfeurope.columns:
    dfeurope[col] = dfeurope[col].apply(func)

# %% [markdown]
# Some city names in the dataframe will lead into wrong coordinate extraction. In this case we will modify the name to be sure be are pulling the right coordinates.

# %%
dfeurope.replace('Sofia', 'Sofiya', inplace=True)
dfeurope.replace('Cracow', 'Krakow', inplace=True)

# %% [markdown]
# Let's take a look at the dataframe and do a quick check to see that everything is as expected

# %%
dfeurope
# Out:
#            Country              City   Jan   Feb   Mar   Apr   May   Jun  \
# 0          Albania            Tirana   6.7   7.8  10.0  13.4  18.0  21.6
# 1          Andorra  Andorra la Vella   2.2   3.5   5.8   7.5  11.5  15.4
# 2          Austria            Vienna   0.3   1.5   5.7  10.7  15.7  18.7
# 3          Belarus             Minsk  −4.5  −4.4   0.0   7.2  13.3  16.4
# 4          Belgium          Brussels   3.3   3.7   6.8   9.8  13.6  16.2
# ..             ...               ...   ...   ...   ...   ...   ...   ...
# 65         Ukraine              Kiev  −3.5  −3.0   1.8   9.3  15.5  18.5
# 66         Ukraine              Lviv  −3.1  −2.2   1.9   8.3  13.8  16.4
# 67         Ukraine            Odessa  −0.5  −0.2   3.5   9.4  15.6  20.0
# 68  United Kingdom         Edinburgh   4.2   4.5   6.2   8.1  10.8  13.5
# 69  United Kingdom            London   4.3   4.5   6.9   8.7  12.1  15.1
#
#      Jul   Aug   Sep   Oct   Nov   Dec  Year
# 0   24.0  23.8  20.7  16.0  11.7   8.1  15.2
# ...

# %%
dfeurope.dtypes
# Out:
# Country    object
# City       object
# Jan        object
# Feb        object
# Mar        object
# Apr        object
# May        object
# Jun        object
# Jul        object
# Aug        object
# Sep        object
# Oct        object
# Nov        object
# Dec        object
# Year       object
# dtype: object

# %% [markdown]
# As you can see, the negative sign is not interpreted as such when importing the data. Also, this leads into a wrong data type in the numeric columns. Finally, we will get rid of the 'Year' and 'Country' columns. Let's fix this!

# %%
dfeurope.replace('−','-',regex=True, inplace = True)

dfeurope.drop('Country', axis=1, inplace=True)
dfeurope.drop('Year', axis=1, inplace=True)

for col in dfeurope.columns:
    if col == 'City':
        pass
    else:
        dfeurope[col] = pd.to_numeric(dfeurope[col],errors='coerce')

# %%
dfeurope
# Out:
#                 City  Jan  Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0             Tirana  6.7  7.8  10.0  13.4  18.0  21.6  24.0  23.8  20.7
# 1   Andorra la Vella  2.2  3.5   5.8   7.5  11.5  15.4  18.8  18.5  14.9
# 2             Vienna  0.3  1.5   5.7  10.7  15.7  18.7  20.8  20.2  15.4
# 3              Minsk -4.5 -4.4   0.0   7.2  13.3  16.4  18.5  17.5  12.1
# 4           Brussels  3.3  3.7   6.8   9.8  13.6  16.2  18.4  18.0  14.9
# ..               ...  ...  ...   ...   ...   ...   ...   ...   ...   ...
# 65              Kiev -3.5 -3.0   1.8   9.3  15.5  18.5  20.5  19.7  14.2
# 66              Lviv -3.1 -2.2   1.9   8.3  13.8  16.4  18.3  17.7  13.0
# 67            Odessa -0.5 -0.2   3.5   9.4  15.6  20.0  22.6  22.3  17.2
# 68         Edinburgh  4.2  4.5   6.2   8.1  10.8  13.5  15.3  15.2  13.0
# 69            London  4.3  4.5   6.9   8.7  12.1  15.1  17.3  17.0  14.3
#
#      Oct   Nov  Dec
# 0   16.0  11.7  8.1
# 1   10.3   5.7  3.0
# 2   10.2   5.1  1.1
# ...

# %%
dfeurope.dtypes
# Out:
# City     object
# Jan     float64
# Feb     float64
# Mar     float64
# Apr     float64
# May     float64
# Jun     float64
# Jul     float64
# Aug     float64
# Sep     float64
# Oct     float64
# Nov     float64
# Dec     float64
# dtype: object

# %% [markdown]
# Much better now! Negative signs are now correct and the data type of the numeric columns is correct.
#
# The next step is to get the coordinates of each city.

# %%
geolocator = Nominatim(user_agent="test")
cities = dfeurope['City']

locations = []
for c in cities:
    locations.append(geolocator.geocode(c))
    
latitudes = [x[0] for x in [x[1] for x in locations]]
longitudes = [x[1] for x in [x[1] for x in locations]]

dfeurope['Lat'] = latitudes
dfeurope['Long'] = longitudes

dfeurope
# Out:
#                 City  Jan  Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0             Tirana  6.7  7.8  10.0  13.4  18.0  21.6  24.0  23.8  20.7
# 1   Andorra la Vella  2.2  3.5   5.8   7.5  11.5  15.4  18.8  18.5  14.9
# 2             Vienna  0.3  1.5   5.7  10.7  15.7  18.7  20.8  20.2  15.4
# 3              Minsk -4.5 -4.4   0.0   7.2  13.3  16.4  18.5  17.5  12.1
# 4           Brussels  3.3  3.7   6.8   9.8  13.6  16.2  18.4  18.0  14.9
# ..               ...  ...  ...   ...   ...   ...   ...   ...   ...   ...
# 65              Kiev -3.5 -3.0   1.8   9.3  15.5  18.5  20.5  19.7  14.2
# 66              Lviv -3.1 -2.2   1.9   8.3  13.8  16.4  18.3  17.7  13.0
# 67            Odessa -0.5 -0.2   3.5   9.4  15.6  20.0  22.6  22.3  17.2
# 68         Edinburgh  4.2  4.5   6.2   8.1  10.8  13.5  15.3  15.2  13.0
# 69            London  4.3  4.5   6.9   8.7  12.1  15.1  17.3  17.0  14.3
#
#      Oct   Nov  Dec        Lat       Long
# 0   16.0  11.7  8.1  41.327948  19.818551
# ...

# %% [markdown]
# Let's visualize the data we have so far

# %%
# create map
map_clusters = folium.Map(location=[dfeurope['Lat'][0], dfeurope['Long'][0]], zoom_start=3)

for lat, lon, poi in zip(dfeurope['Lat'], dfeurope['Long'], dfeurope['City']):
    label = folium.Popup(str(poi) , parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        fill=True,
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's also check the monthly temperatures to see if we can already see some insights in the data.

# %%
temp_check = dfeurope.drop(['City','Lat','Long'], axis=1)

# %%
f, ax = plt.subplots(figsize=(18, 7))
plt.plot(temp_check.T)
ax.set(xlabel='Month', ylabel='Temperatures in Degrees ºC')
plt.title('Monthly average Temperatures')
# Out:
# Text(0.5, 1.0, 'Monthly average Temperatures')

# %% [markdown]
# Most of the temperatures follow the same shape with the exception of one city. This is due to the fact that Las Palmas de Gran Canarias in the Canary Islands have a sub-tropical climate. This might affect the results so we decide to remove this entry from the dataset.

# %%
dfeurope = dfeurope[~dfeurope.City.str.contains("Las Palmas de Gran Canaria")]

# %%
dfeurope.reset_index(inplace=True)
dfeurope.drop('index', axis=1, inplace=True)

# %%
dfeurope
# Out:
#                 City  Jan  Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0             Tirana  6.7  7.8  10.0  13.4  18.0  21.6  24.0  23.8  20.7
# 1   Andorra la Vella  2.2  3.5   5.8   7.5  11.5  15.4  18.8  18.5  14.9
# 2             Vienna  0.3  1.5   5.7  10.7  15.7  18.7  20.8  20.2  15.4
# 3              Minsk -4.5 -4.4   0.0   7.2  13.3  16.4  18.5  17.5  12.1
# 4           Brussels  3.3  3.7   6.8   9.8  13.6  16.2  18.4  18.0  14.9
# ..               ...  ...  ...   ...   ...   ...   ...   ...   ...   ...
# 64              Kiev -3.5 -3.0   1.8   9.3  15.5  18.5  20.5  19.7  14.2
# 65              Lviv -3.1 -2.2   1.9   8.3  13.8  16.4  18.3  17.7  13.0
# 66            Odessa -0.5 -0.2   3.5   9.4  15.6  20.0  22.6  22.3  17.2
# 67         Edinburgh  4.2  4.5   6.2   8.1  10.8  13.5  15.3  15.2  13.0
# 68            London  4.3  4.5   6.9   8.7  12.1  15.1  17.3  17.0  14.3
#
#      Oct   Nov  Dec        Lat       Long
# 0   16.0  11.7  8.1  41.327948  19.818551
# ...

# %% [markdown]
# Now it is time to start the machine learning process. As we are going to use unsupervised clustering and more specific KNN clustering, we need to find out wich is the best K for our dataset. In order to find out we will iterate over the dataset with different K and use the Silhouette score to evaluate the best K.

# %%
from sklearn.metrics import silhouette_score

grouped_clustering = dfeurope.drop('City', 1)


sil = []
kmax = 15

# dissimilarity would not be defined for a single cluster, thus, minimum number of clusters should be 2
for k in range(2, kmax+1):
  kmeans = KMeans(n_clusters = k).fit(grouped_clustering)
  labels = kmeans.labels_
  sil.append(silhouette_score(grouped_clustering, labels, metric = 'euclidean'))

# %%
plt.plot(range(2, kmax+1), sil)
plt.title('Silhouette score')
plt.xlabel('K')
plt.ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# The Silhouette score is widely used in unsupervised clustering to find out the best K in KNN algorithm. The best K as defined in the Silhouette score is the one with the maximum value. In the graph we can see that the maximum score corresponds to K=4. Let's use this in our analysis.

# %%
# set number of clusters
kclusters = 4

grouped_clustering = dfeurope.drop('City', 1)

# run k-means clustering
kmeans =KMeans(n_clusters=kclusters, random_state=0).fit(grouped_clustering)

# %%
#let's add the cluster label into the dataset
grouped_clustering.insert(0, 'Cluster_Labels', kmeans.labels_)

# %% [markdown]
# Finally we can check in a map the different clusters

# %%
latitude = grouped_clustering.Lat[10]
longitude = grouped_clustering.Long[10]

# create map

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=4)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
#for lat, lon, poi, cluster in zip(dfeu_cities['Lat'], dfeu_cities['Long'], dfeu_cities['City'], grouped_clustering['Cluster_Labels']):
for lat, lon, poi, cluster in zip(grouped_clustering['Lat'], grouped_clustering['Long'], dfeurope['City'], grouped_clustering['Cluster_Labels']):
    label = folium.Popup(str(poi) + '\n Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As we can see in the map, we have 4 different clusters. Geographically we see the clusters are distributed in southern europe, west-central Europe, central-east Europe and northern Europe. This map actually correlates very well to the climate map of Europe. That is an interesting finding that tells us more than we expected. We can say that the clustering works. Let's take a look at it.

# %% [markdown]
# ![European Climates](http://2.bp.blogspot.com/-4dgHhmOxKXY/UTZAN40tCjI/AAAAAAAABAQ/fGKksN_pHU0/s1600/European+climates.PNG)

# %% [markdown]
# Let's now visualize the average value of each cluster per month

# %%
grouped_clustering_graph = grouped_clustering.drop(['Lat', 'Long'], axis =1)

# %%
grouped_clustering_graph.groupby('Cluster_Labels').mean()
# Out:
#                      Jan        Feb        Mar        Apr        May  \
# Cluster_Labels
# 0              -6.020000  -5.853333  -1.740000   3.893333   9.933333
# 1               9.625000  10.268750  12.450000  14.862500  18.843750
# 2               0.062500   1.341667   5.237500  10.512500  15.620833
# 3               2.392857   2.957143   5.564286   8.364286  12.257143
#
#                       Jun        Jul        Aug        Sep        Oct  \
# Cluster_Labels
# 0               14.346667  16.793333  15.280000  10.486667   5.380000
# 1               22.793750  25.687500  25.756250  22.575000  18.412500
# 2               19.075000  21.291667  20.891667  16.279167  11.079167
# 3               15.192857  17.314286  16.978571  13.785714  10.007143
#
#                       Nov        Dec
# Cluster_Labels
# 0               -0.266667  -4.106667
# 1               13.743750  10.668750
# 2                5.475000   1.350000
# 3                5.728571   3.092857

# %%
transposed_gr = grouped_clustering_graph.groupby('Cluster_Labels').mean().T

f, ax = plt.subplots(figsize=(18, 6))
for i in range(0,transposed_gr.shape[1]):
    plt.plot(transposed_gr.index,transposed_gr[i], label='Cluster {}'.format(i), color = rainbow[i-1])
    
plt.title('Average temperature per cluster')
plt.ylabel('Temperature in degrees ºC')
ax.legend(loc='upper left')

# %% [markdown]
# Finally let's check out each of the cities average temperature

# %%
f, ax = plt.subplots(figsize=(18, 6))

for i in range(0,grouped_clustering_graph.T.shape[1]):
    plt.plot(grouped_clustering_graph.T.index[1:-1],grouped_clustering_graph.T[i][1:-1],color = rainbow[int(grouped_clustering_graph.T[i][0]-1)])
    
plt.title('Average temperature per City')
plt.ylabel('Temperature in degrees ºC')
# Out:
# Text(0, 0.5, 'Temperature in degrees ºC')

# %% [markdown]
# In order to have a better understanding of each cluster and the distribution of the observations, we can use boxplots. As we can see from the plot, the four clusters are well distinguished. Clusters 2 and 3, which correspond to west and east Europe have quite a similar temperature range but cluster 3 sees less variation. Cluster 0 and 1 are well differentiated.

# %%
new_rainbow = []
for i in range(0,len(rainbow)):
    new_rainbow.append(rainbow[i-1])
    
f, ax = plt.subplots(figsize=(9, 6))
sns.boxplot(data=transposed_gr, palette = new_rainbow)
sns.stripplot(data=transposed_gr,
              size=4, color=".3", linewidth=0)
# Out:
# <AxesSubplot:xlabel='Cluster_Labels'>

# %% [markdown]
# Finally, let's use a heatmap plot to have a clearer way of visualizing the temperature variations of each cluster

# %%
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(transposed_gr, annot=True, fmt="f", linewidths=.5, ax=ax, cmap='coolwarm', center=0)
# Out:
# <AxesSubplot:xlabel='Cluster_Labels'>

# %% [markdown]
# Now, that we have our temperature data clustered, let's use Foursquare to retrieve the number of Festivals per city.
#
# First we need to declare all the credentials to connect to the Foursquare API

# %%
CLIENT_ID = 'JBKRKQTWGGIFBBARW0KFOM3L5HTG3FBQQZERTKXNJA4BRCAT' # your Foursquare ID
CLIENT_SECRET = 'LW5YCQGBYXFSA4GT3YPYUVN3AHIQZTKIPFKMQBGHYXKODE0J' # your Foursquare Secret
ACCESS_TOKEN = 'LDUMD0YXAX4D2VKOBJGBFAR4XC11UPDDWN35GGQ5AJCF0KXB' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JBKRKQTWGGIFBBARW0KFOM3L5HTG3FBQQZERTKXNJA4BRCAT
# CLIENT_SECRET:LW5YCQGBYXFSA4GT3YPYUVN3AHIQZTKIPFKMQBGHYXKODE0J

# %% [markdown]
# We will now define our query and radius and build up our URL. We will store all the results in an array and create a new dataframe

# %%
search_query = 'Festival'
radius = 10000

festival_arr = []
for i in range(0, len(dfeurope['Lat'])):
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(
    CLIENT_ID, CLIENT_SECRET, dfeurope.Lat[i], dfeurope.Long[i],ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
    
    results = requests.get(url).json()
    festivals = results['response']['venues']
    festival_arr.append(len(festivals))
    
dfeu_cities_cl_fest = dfeurope

dfeu_cities_cl_fest['Cluster_Labels'] = grouped_clustering['Cluster_Labels']
dfeu_cities_cl_fest['festivals'] = festival_arr

dfeu_cities_cl_fest
# Out:
#                 City  Jan  Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0             Tirana  6.7  7.8  10.0  13.4  18.0  21.6  24.0  23.8  20.7
# 1   Andorra la Vella  2.2  3.5   5.8   7.5  11.5  15.4  18.8  18.5  14.9
# 2             Vienna  0.3  1.5   5.7  10.7  15.7  18.7  20.8  20.2  15.4
# 3              Minsk -4.5 -4.4   0.0   7.2  13.3  16.4  18.5  17.5  12.1
# 4           Brussels  3.3  3.7   6.8   9.8  13.6  16.2  18.4  18.0  14.9
# ..               ...  ...  ...   ...   ...   ...   ...   ...   ...   ...
# 64              Kiev -3.5 -3.0   1.8   9.3  15.5  18.5  20.5  19.7  14.2
# 65              Lviv -3.1 -2.2   1.9   8.3  13.8  16.4  18.3  17.7  13.0
# 66            Odessa -0.5 -0.2   3.5   9.4  15.6  20.0  22.6  22.3  17.2
# 67         Edinburgh  4.2  4.5   6.2   8.1  10.8  13.5  15.3  15.2  13.0
# 68            London  4.3  4.5   6.9   8.7  12.1  15.1  17.3  17.0  14.3
#
#      Oct   Nov  Dec        Lat       Long  Cluster_Labels  festivals
# ...

# %% [markdown]
# We can use a bar plot to see the number of festivals per city and colored by cluster.

# %%
dfeu_cities_cl_fest = dfeu_cities_cl_fest.sort_values('Cluster_Labels')

# %%
f, ax = plt.subplots(figsize=(25, 10))
plt.xticks(rotation=70)
sns.barplot(x="City", y="festivals", data=dfeu_cities_cl_fest, hue='Cluster_Labels', hue_order=[0,1,2,3], palette = new_rainbow,dodge=False)
# Out:
# <AxesSubplot:xlabel='City', ylabel='festivals'>

# %% [markdown]
# From this visualization we cannot really see what cluster is the one containing more festivals. Let's calculate the average festivals per cluster and visualize it. We use the average and the sum of all the festivals per cluster because clusters do not contain the same number of cities and results will not be representative.

# %%
f, ax = plt.subplots(figsize=(25, 10))
plt.xticks(rotation=70)
sns.barplot(data=dfeu_cities_cl_fest.groupby('Cluster_Labels').mean().T, palette = new_rainbow,dodge=False)
# Out:
# <AxesSubplot:xlabel='Cluster_Labels'>

# %% [markdown]
# ## Results and Discussion

# %% [markdown]
# The analysis shows a positive correlation between temperature and the number of festivals. We were able to show only using data that, on average, regions with warmer weather held more open-air festivals than regions with colder temperatures.
#
# The clustering matched quite well the different climate types which supports the fact that the clustering seems correct. Also the analysis of the festivals per cluster shows the positive correlation. However, the list of cities used in the analysis is not geographically balanced. There are regions like France or the Scandinavian countries where we can see a lot of data gaps. This creates an heterogeneous distribution that affects our results.
#
# Regarding the Foursquare API, we found out that it is not possible to segmentate between types of festivals. We did some research on using different terms in the query but ended up using only the keyword 'Festival' as it was the most generic one.
#
# To summarize, we think the results support our hypothesis however, it will be great to use a more geographically homogeneous distributed data and repeat the analysis to see if this refines the results in the number of clusters and thus the distribution of the results.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The purpose of the analysis was to validate the hypothesis that regions with warmer temperatures held more open-air festivals. Using KNN clustering allowed us to cluster locations by similar temperature and check at the geographical distribution. A cross validation with a climate map of Europe supports the correctness of the clustering. Finally, segmenting the festivals by cluster lead into the final conclusion that areas with warmer temperatures held on average more festivals.
